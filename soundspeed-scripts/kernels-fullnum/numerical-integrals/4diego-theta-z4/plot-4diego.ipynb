# %%
import numpy as np
import matplotlib.pyplot as plt

plt.rcParams.update({
    "text.usetex": True,
    "font.family": "serif",
    "font.serif": ["Computer Modern"],
})

# %%
plt.figure(figsize=(6,4.5),dpi=130)

kplt,dcTc22, dcTc22_EdS, dcTx22, dcTx22_EdS, PL_cc, TL_x =np.loadtxt('/home/fverdian/class/soundspeed-scripts/kernels-fullnum/numerical-integrals/checks-Theta/dT22EdSh-kJ0p45-fx0p1-N1000.txt', unpack=True)

kplt,dcTc13, dcTc13_EdS, dcTx13, dcTx13_EdS, PL_cc, TL_x =np.loadtxt('/home/fverdian/class/soundspeed-scripts/kernels-fullnum/numerical-integrals/checks-Theta/dT13EdSh-kJ0p45-fx0p1-N1000.txt', unpack=True)

plt.plot(kplt, dcTx13, 'b', label=r'$P^{13}_{\delta_c\Theta_\chi}$, z=1', linewidth=1)
plt.plot(kplt, dcTx13_EdS, 'b--', linewidth=1)

plt.plot(kplt, dcTx22, 'r', label=r'$P^{22}_{\delta_c\Theta_\chi}$, z=1', linewidth=1)
plt.plot(kplt, dcTx22_EdS, 'r--', linewidth=1)
plt.plot(kplt, dcTx22 + dcTx13, 'purple', label=r'$P^{1l}_{\delta_c\Theta_\chi}$ , z=1', linewidth=1)

plt.plot(kplt, dcTx22_EdS+dcTx13_EdS, 'gray', linestyle='--', linewidth=0.8)
# plt.plot(kplt, PL_cc, 'k', linestyle='--', linewidth=0.8, label=r'$P^{1l}_{\delta_c\Theta_c}$ EdS')


kplt,dcTc22, dcTc22_EdS, dcTx22, dcTx22_EdS, PL_cc, TL_x =np.loadtxt('/home/fverdian/class/soundspeed-scripts/kernels-fullnum/numerical-integrals/4diego-theta-z4/dT22EdSh-kJ0p45-fx0p1-N1000.txt', unpack=True)

kplt,dcTc13, dcTc13_EdS, dcTx13, dcTx13_EdS, PL_cc, TL_x =np.loadtxt('/home/fverdian/class/soundspeed-scripts/kernels-fullnum/numerical-integrals/4diego-theta-z4/dT13EdSh-kJ0p45-fx0p1-N1000.txt', unpack=True)

plt.plot(kplt, dcTx13, 'b', label=r'$P^{13}_{\delta_c\Theta_\chi}$, z=4', linewidth=1)
plt.plot(kplt, dcTx13_EdS, 'b--',linewidth=1)

plt.plot(kplt, dcTx22, 'r', label=r'$P^{22}_{\delta_c\Theta_\chi}$, z=4', linewidth=1)
plt.plot(kplt, dcTx22_EdS, 'r--', linewidth=1)
plt.plot(kplt, dcTx22 + dcTx13, 'purple', label=r'$P^{1l}_{\delta_c\Theta_\chi}$ , z=4', linewidth=1)

plt.plot(kplt, dcTx22_EdS+dcTx13_EdS, 'gray', linestyle='--', linewidth=0.8)

plt.axhline(y=0.,linestyle=':', color='k', linewidth=0.3)

plt.xscale('log')
# plt.yscale('log')

plt.ylabel(r"$P$", fontsize=15)
plt.legend(fontsize=13, loc='center right')
plt.xlabel(r'$k$', fontsize=13)
# plt.savefig('/home/fverdian/class/soundspeed-scripts/kernels-fullnum/numerical-integrals/4diego-theta-z4/breakdown.pdf', bbox_inches='tight')
plt.show()

# %%
plt.figure(figsize=(6,4.5),dpi=130)

kplt,dcTc22, dcTc22_EdS, dcTx22, dcTx22_EdS, PL_cc, TL_x =np.loadtxt('/home/fverdian/class/soundspeed-scripts/kernels-fullnum/numerical-integrals/checks-Theta/dT22EdSh-kJ0p45-fx0p1-N1000.txt', unpack=True)

kplt,dcTc13, dcTc13_EdS, dcTx13, dcTx13_EdS, PL_cc, TL_x =np.loadtxt('/home/fverdian/class/soundspeed-scripts/kernels-fullnum/numerical-integrals/checks-Theta/dT13EdSh-kJ0p45-fx0p1-N1000.txt', unpack=True)

plt.plot(kplt, dcTx22 + dcTx13, 'purple', label=r'$P^{1l}_{\delta_c\Theta_\chi}$ , z=1', linewidth=1)
plt.plot(kplt, dcTx22_EdS+dcTx13_EdS, 'gray', linewidth=0.8)
plt.plot(kplt, PL_cc, 'k', linewidth=0.8, label=r'$P^{1l}_{\delta_c\Theta_\chi}$ EdS')


kplt,dcTc22, dcTc22_EdS, dcTx22, dcTx22_EdS, PL_cc, TL_x =np.loadtxt('/home/fverdian/class/soundspeed-scripts/kernels-fullnum/numerical-integrals/4diego-theta-z4/dT22EdSh-kJ0p45-fx0p1-N1000.txt', unpack=True)

kplt,dcTc13, dcTc13_EdS, dcTx13, dcTx13_EdS, PL_cc, TL_x =np.loadtxt('/home/fverdian/class/soundspeed-scripts/kernels-fullnum/numerical-integrals/4diego-theta-z4/dT13EdSh-kJ0p45-fx0p1-N1000.txt', unpack=True)

plt.plot(kplt, dcTx22 + dcTx13, 'purple', linestyle='--',label=r'$P^{1l}_{\delta_c\Theta_\chi}$ , z=4', linewidth=1)
plt.plot(kplt, dcTx22_EdS+dcTx13_EdS, 'gray', linestyle='--', linewidth=0.8)
plt.plot(kplt, PL_cc*TL_x, 'k', linestyle='--', linewidth=0.8, label=r'$P^{1l}_{\delta_c\Theta_\chi}$ EdS')

plt.xscale('log')
plt.yscale('log')

plt.ylabel(r"$P$", fontsize=15)
plt.legend(fontsize=13, loc='upper right')
plt.xlabel(r'$k$', fontsize=13)
# plt.savefig('/home/fverdian/class/soundspeed-scripts/kernels-fullnum/numerical-integrals/4diego-theta-z4/loopandlin.pdf', bbox_inches='tight')
plt.show()
