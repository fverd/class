# %%
import numpy as np
import numpy as np
from scipy.interpolate import interp1d, interp2d, RectBivariateSpline, LinearNDInterpolator, NearestNDInterpolator
from scipy.integrate import odeint
import concurrent.futures, itertools
import matplotlib.pyplot as plt
import pickle, tqdm, functools
import vegas
plt.rcParams.update({
    "text.usetex": True,
    "font.family": "serif",
    "font.serif": ["Computer Modern"],
})

# %% [markdown]
# ## Definitions and EdS case

# %%
with open('/home/fverdian/class/soundspeed-scripts/1loop/Pk-lin-int.pkl', 'rb') as f:
    Plin_int = pickle.load(f)
fact=(2*np.pi)**3

def F3(k,q,mu):
    k2=k*k;q2=q*q;mu2=mu*mu
    kMq2 = k2 + q2 - 2*k*q*mu 
    kPq2 = k2 + q2 + 2*k*q*mu 

    res1 = 1/kMq2*(5/126*k2-11/108*k*q*mu+7/108*q2*mu2-1/54*k2*k2*mu2/q2+4/189*k2*k*mu2*mu/q-23/756*k2*k*mu/q+25/252*k2*mu2-2/27*k*q*mu2*mu)
    res2 = 1/kPq2*(5/126*k2+11/108*k*q*mu-7/108*q2*mu2-4/27*k2*k2*mu2/q2-53/189*k2*k*mu2*mu/q+23/756*k2*k*mu/q-121/756*k2*mu2-5/27*k*q*mu2*mu)
    return res1+res2

def F2(k,q,mu):
    k2=k*k;q2=q*q;mu2=mu*mu
    kMq2 = k2 + q2 - 2*k*q*mu 
    return (k2*(7*k*q*mu+3*q2)-10*k2*q2*mu2)/(14*q2*kMq2)

def alpha(k1,k2,cT):
    return 1+cT*k2/k1

def alphas(k1,k2,cT):
    return 1+0.5*cT*(k2/k1+k1/k2)

def beta(k1,k2,cT):
    t1=k1*k1+k2*k2+2*k1*k2*cT
    t2=k1*k2*cT
    t3=2.*k1*k1*k2*k2
    return t1*t2/t3

# %%
fx=0.1
fullt=np.linspace(-5,3, 100)
teval=10
idx_eta=np.abs(fullt - (0.)).argmin()
kref=0.1

# %%
# this is solved fot k=0.1 (for which tildeeta = eta) and then I shift it using the smmetry
def lin_system(w,t):
    dc,Tc = w
    ddcdt = Tc
    dTcdt = -0.5*Tc+1.5*(1-fx)*dc
    return [ddcdt, dTcdt]
# Initial conditions
w0 = [1,1-3/5*fx]
# Solve the differential equation
tlin=np.linspace(fullt[0],fullt[-1],1000)

linsol = odeint(lin_system, w0, tlin)

g_c_int=interp1d(tlin,linsol[:,1]/linsol[:, 0],bounds_error=False,  fill_value='extrapolate')

plt.figure(figsize=(5,2), dpi=130);plt.ylim([0,1])
plt.plot(fullt, g_c_int(fullt), 'b', label=r'$\Theta$')
plt.show()

# %%
#--------
# 2nd order
#--------
def solve_second_order(triplet, return_timedep=False):
    k1 , k2, cT = triplet
    def F2_system(w, t):
        Fc2,Gc2 = w
        fact=(g_c_int(t-2*np.log(k1))+g_c_int(t-2*np.log(k2)))
        SF2=0.5*g_c_int(t-2*np.log(k2))*alpha(k1,k2,cT)+0.5*g_c_int(t-2*np.log(k1))*alpha(k2,k1,cT)
        dGc2dt = -(0.5+fact)*Gc2 + 1.5 *((1-fx)*Fc2) +g_c_int(t-2*np.log(k1))*g_c_int(t-2*np.log(k2))*beta(k1,k2,cT)
        dFc2dt = -fact*Fc2 + Gc2 + SF2
        return [dFc2dt, dGc2dt]
    Fc2_0=(5./7.+6/245*fx)*alphas(k1,k2,cT)+(2./7.-6/245*fx)*beta(k1,k2,cT)
    Gc2_0=(3./7-51/245*fx)*alphas(k1,k2,cT)+(4./7-96/245*fx)*beta(k1,k2,cT)
    sol = odeint(F2_system, [Fc2_0,Gc2_0], fullt, rtol=0.001)
    if return_timedep:
        return sol
    return sol[idx_eta]

# %%
kp=0.15
qp=100
mup=1.
kMq = np.sqrt(kp**2 + qp**2 - 2*kp*qp*mup)
cT12 = (kp*mup-qp)/kMq
sol=solve_second_order([qp,kMq,cT12], return_timedep=True)

plt.figure(figsize=(5,3.5), dpi=140)
plt.plot(fullt, sol[:,0], 'b', label=r'$F_c^{(2)}$')

Fc2_0=(5./7.+6/245*fx)*alphas(qp,kMq,cT12)+(2./7.-6/245*fx)*beta(qp,kMq,cT12)
def G2F2combo(k1,k2,cT):
    return [(5./7+6/245*fx)*alphas(k1,k2,cT)+(2./7-6/245*fx)*beta(k1,k2,cT),(3./7-3*17/245*fx)*alphas(k1,k2,cT)+(4./7-3*32/245*fx)*beta(k1,k2,cT)]
plt.axhline(Fc2_0, color='b', linestyle=':', linewidth=0.7)
plt.axhline(G2F2combo(qp,kMq,cT12)[0], color='m', linewidth=0.7)

plt.axhline(F2(kp,qp,mup), color='b', linewidth=0.7)
plt.fill_between(fullt, F2(kp,qp,mup)*(1-fx),F2(kp,qp,mup)*(1+fx), alpha=0.05, color='b')

# plt.axhline(F3(kp,qp,mup), color='g', linewidth=0.7)

plt.legend()
# plt.xlim([-8,8])

# plt.yscale('log')
plt.title(r'Second order at $k='+'%.2f'%kp+r'$, $q='+'%.2f'%qp+r'$, $\mu='+'%.1f'%mup+r'$')
plt.xlabel(r'$\eta$', fontsize=14)
# plt.savefig('/home/fverdian/class/soundspeed-scripts/figure/F2_kers_eta.pdf', bbox_inches='tight')

plt.show()
# Out:
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4628506089752D+01

# %%
kp=0.15
qp=1000
mup=1.

print(solve_second_order([kp,qp,mup]), G2F2combo(kp,qp,mup))
# Out:
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4660783283932D+01
# [3334.32652647 3129.22503651] [3334.3334083333334, 3134.2734038333333]

# %%
#--------
# 3rd order
#--------
def DeltaF3_ennio(k,q,mu):
    x2=(k/q)**2;mu2=mu*mu
    num=4*(mu2-1)*x2*(-49*mu2+(5*mu2+22)*x2 +22)
    den=945*(x2*x2+(2-4*mu2)*x2+1)
    return num/den

def G2F2combo(k1,k2,cT):
    return [(5./7+6/245*fx)*alphas(k1,k2,cT)+(2./7-6/245*fx)*beta(k1,k2,cT),(3./7-3*17/245*fx)*alphas(k1,k2,cT)+(4./7-3*32/245*fx)*beta(k1,k2,cT)]

def solve_F3_for_k(triplet, return_timedep=False):
    k , q, mu = triplet
    
    ker2_k_mq_full=solve_second_order([k,q,-mu], return_timedep=True)
    ker2_k_q_full=solve_second_order([k,q,mu], return_timedep=True)
    # ker2_k_mq_full=np.tile(G2F2combo(k,q,-mu), (fullt.shape[0], 1))
    # ker2_k_q_full=np.tile(G2F2combo(k,q,mu), (fullt.shape[0], 1))
    def F3_system(w, t):

        Fc3,Gc3 = w
        fact=(g_c_int(t-2*np.log(k))+2*g_c_int(t-2*np.log(q)))

        idx_t_F3=np.abs(fullt - t).argmin()
        ker2_k_mq=ker2_k_mq_full[idx_t_F3]
        ker2_k_q=ker2_k_q_full[idx_t_F3]

        #F3_c and G3_c
        kMq = np.sqrt(k*k + q*q - 2*k*q*mu)
        cT=(k*mu-q)/kMq
        SF3=g_c_int(t-2*np.log(q))*alpha(q,kMq,cT)*ker2_k_mq[0]+alpha(kMq,q,cT)*ker2_k_mq[1]
        SG3=g_c_int(t-2*np.log(q))*beta(kMq,q,cT)*2*ker2_k_mq[1]
        kPq = np.sqrt(k*k + q*q + 2*k*q*mu)
        cT=-(k*mu+q)/kPq
        SF3+=g_c_int(t-2*np.log(q))*alpha(q,kPq,cT)*ker2_k_q[0]+alpha(kPq,q,cT)*ker2_k_q[1]
        SG3+=g_c_int(t-2*np.log(q))*beta(kPq,q,cT)*2*ker2_k_q[1]

        dFc3dt = -fact*Fc3 + Gc3 + SF3/3
        dGc3dt = -(0.5+fact)*Gc3 + 1.5*((1-fx)*Fc3) + SG3/3

        return [dFc3dt, dGc3dt]
    
    tsol=np.linspace(np.log(k/kref)-10,np.log(k/kref)+18,100)
    sol = odeint(F3_system, [F3(k,q,mu)-1/7*fx*DeltaF3_ennio(k,q,mu),F3(k,q,mu)-1/7*fx*DeltaF3_ennio(k,q,mu)], tsol, rtol=0.001)
    if return_timedep:
        return [tsol,sol[:,0]]
    return sol[idx_eta,0]

# %%
kp=0.15
qp=0.01
mup=1.
kMq = np.sqrt(kp**2 + qp**2 - 2*kp*qp*mup)
cT12 = (kp*mup-qp)/kMq
solF3=solve_F3_for_k([kp,qp,mup], return_timedep=True)

plt.figure(figsize=(4,3.5), dpi=130)

plt.plot( solF3[0],solF3[1], 'g', label=r'$F_c^{(3)}$')

# plt.axhline(F2(kp,qp,mup), color='b', linewidth=0.7)
plt.axhline(F3(kp,qp,mup), color='g', linewidth=0.7)
plt.axhline(F3(kp,qp,mup)-1/7*fx*DeltaF3_ennio(kp,qp,mup), color='r', linewidth=0.7)
plt.axhline(F3(kp,qp,mup)-1/7*fx*DeltaF3_mio(kp,qp,mup), color='m', linewidth=0.7)

plt.legend()
# plt.ylim([F3(kp,qp,mup)*0.9,F3(kp,qp,mup)*1.1])

# plt.yscale('log')
plt.title(r'Second order at $k='+'%.2f'%kp+r'$, $q='+'%.2f'%qp+r'$, $\mu='+'%.1f'%mup+r'$')
plt.xlabel(r'$\eta$', fontsize=14)
# plt.savefig('/home/fverdian/class/soundspeed-scripts/figure/F2_kers_eta.pdf', bbox_inches='tight')

plt.show()
# Out:
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658549218346D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658548652277D+01

# %%
#--------
def onmu_int(mu, kev, q, calcP13=True, calcP22=True, EdS=False):
    P13=0
    if calcP13:
        if EdS:
            F3_val=F3(kev,q,mu)
        else:
            F3_val=solve_F3_for_k([kev,q,mu])
        # F3_val=F3(kev,q,mu)
        P13+=6*q*q*F3_val*Plin_int(q)*Plin_int(kev)
    kMq = np.sqrt(kev*kev + q*q - 2*kev*q*mu)
    kPq = np.sqrt(kev*kev + q*q + 2*kev*q*mu)
    P22=0
    if calcP22:
        if kMq>q:
            if EdS:
                F2_val=F2(kev,q,mu)
            else:
                cT12 = (kev*mu-q)/kMq
                F2_val=solve_second_order([q,kMq,cT12])[0]
            P22+=2*q*q*F2_val*F2_val*Plin_int(q)*Plin_int(kMq)
        if kPq>q:
            if EdS:
                F2_val=F2(kev,q,-mu)
            else:
                cT12 = -(kev*mu+q)/kPq
                F2_val=solve_second_order([q,kPq,cT12])[0]
            P22+=2*q*q*F2_val*F2_val*Plin_int(q)*Plin_int(kPq)
    return (P13+P22)*4*np.pi/fact
    
reslist22=[];reslist13=[]
kp=0.15
qlist=np.logspace(-5,-2,10)
for qEval in qlist:
    print(f'P22 at q={qEval:.2e}',end='\r')
    integ = vegas.Integrator([0., 1.],mpi=True, nproc=48)
    result = integ(functools.partial(onmu_int, kev=kp, q=qEval,calcP22=True, calcP13=False, EdS=False),neval=50)
    reslist22.append(result.mean)

    print(f'P13 at q={qEval:.2e}',end='\r')
    result = integ(functools.partial(onmu_int, kev=kp, q=qEval,calcP22=False, calcP13=True,EdS=False),neval=50)
    reslist13.append(result.mean)
# Out:
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658549337271D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658548499807D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658551143667D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658555240428D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658568586060D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#  intdy--  t (=r1) illegal
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658550124666D+01
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658576708690D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658550018525D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658546693428D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658542596734D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658547712421D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658529251771D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658521129885D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658547818562D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658555662297D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658550009639D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658549535119D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658549792717D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658549330491D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658549866334D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658542174875D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658549351115D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658549318317D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658549157642D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658547827447D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658548301963D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658548506587D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658548485962D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658549176707D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658548518760D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658548679429D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658547970751D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658549214065D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658549164134D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658549096995D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658548660365D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658549055076D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658549382980D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658549062703D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658548623009D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658549126155D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658548672937D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658550254283D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658548740072D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658549240537D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658548781988D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658549011101D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658548774362D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658548710914D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658550221919D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658547582805D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658549339241D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658549092932D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658549114643D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658549559553D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658548825960D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658548955258D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658548976160D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658548920520D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658549257997D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658548497837D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658548744134D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658548277529D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658548993690D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658548881797D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658548860897D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658549262590D+01
#  intdy--  t (=r1) illegal
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above message,  r1 = -0.4838383838384D+01
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658548579078D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658548916530D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658549425875D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658548843369D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658549122038D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658548574486D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658549026658D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658547615169D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658548411204D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658548722426D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658548715031D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658548810404D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658548964981D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658555321876D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658548596538D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658553340863D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658551378651D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658548960254D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658548951385D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658548872075D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658542515289D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658544496260D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658546458446D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658549158465D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658548876801D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658548885670D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658548044368D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658548678606D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658548454098D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658549778075D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658548059009D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658549776982D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658549624152D+01
#  intdy--  t (=r1) illegal
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658549451071D+01
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658552941155D+01
#  intdy--  t (=r1) illegal
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658551128972D+01
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658550933580D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658549453665D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658549558362D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658548060102D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658548212931D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658548386009D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658546903513D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658544895962D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658548383416D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658546708123D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658548278720D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658549342979D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658549286121D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658549255759D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658549231142D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658549208377D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658549270917D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658549255870D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658548494099D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658549191117D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658549093839D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658548550955D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658548581316D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658548628696D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658548566158D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658548581206D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658549161147D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658548645956D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658548743229D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658549112073D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658549082363D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658549095867D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658549154251D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658549112420D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658548675925D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658549088987D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658549118012D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658549034443D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658548724995D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658549059042D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658548741200D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658548724648D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658549002858D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658548748080D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658548719056D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658548802620D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658548778022D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658549054987D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658549032676D+01
#  intdy--  t (=r1) illegal
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658549023294D+01
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658549018703D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658549032772D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658548997039D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658548948050D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658548980884D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658548940390D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658548782078D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658548804387D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658548818358D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658548804290D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658548840020D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658548889004D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658548856173D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658548896663D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658548965844D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658548920839D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658548936067D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658548981642D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658548961539D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658548948334D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658548949859D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658548871212D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658548754703D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658548916212D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658548900985D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658548855416D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658548875517D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658548888720D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658548887195D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658548970921D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658548948612D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658548993989D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658548605932D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658548866136D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658548888442D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658548843070D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658548682821D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658548813768D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658548834201D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658551432331D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658549910497D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658551523556D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658550132009D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658550974693D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658549291236D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658549274738D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658549342280D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658546404766D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658547926589D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658546313542D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658547705078D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658546862401D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658548545841D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658548562338D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658548494797D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658549545925D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658549379708D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658549388885D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658549591975D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658549514633D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658549244480D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658549199846D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658549220322D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658548291157D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658548457371D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658548448194D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658548245107D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658548322448D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658548592595D+01
#  intdy--  t (=r1) illegal
# ...
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4659161477700D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4659122553299D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4659099388875D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4660704966595D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4659086895428D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4659560371819D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658083050315D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4657967581397D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658005888364D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658028652186D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4656436792747D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658040918142D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4657572816228D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4629885046444D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4659526330771D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658916911916D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658804462928D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658898381465D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658818860810D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658806878045D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658973605273D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658766418313D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658692222157D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658717022067D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4657606589459D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658314620947D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658224613162D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658312324613D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658709444138D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658350643824D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658419953315D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658396940623D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658762441228D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658638812390D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658632829527D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658403989916D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658647616967D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658591375319D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658609830231D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658585418257D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658573595124D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658354392221D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658474338746D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658577821810D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658460900872D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658511610112D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658495092485D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658516915064D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658527404140D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4661295003134D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658649270941D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658684854001D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658523660522D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658590444761D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4660622577475D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4655852455571D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658459393425D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658566528924D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658426757972D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658151685392D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658468910567D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658512439677D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4656518477468D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658701915965D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658794633541D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658533647265D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658800748278D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658572859297D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658410977865D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658206706663D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658323955609D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658318150771D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658528055163D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658300915423D+01
# P13 at q=1.00e-02

# %%
kp=0.15
qp=1.e-4
integ = vegas.Integrator([0., 1.],mpi=True, nproc=48)
result = integ(functools.partial(onmu_int, kev=kp, q=qp,calcP22=True, calcP13=False, EdS=False),neval=100)
res22=result.mean
print(f'P22={result},now P13')
result = integ(functools.partial(onmu_int, kev=kp, q=qp,calcP22=False, calcP13=True,EdS=False),neval=100)
res13=result.mean
print(f'P13={result}')
print(f'P22={res22:.3f}, -P13={-res13:.3f}, reldiff={(res22+res13)/res22:.0e}')
# Out:
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658549112715D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658548723220D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658645180069D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658654035840D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658570892694D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658610865641D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658566648585D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658570497754D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658560919512D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658452677026D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658526947417D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658443824694D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658486980983D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658531191175D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658536919837D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658527342322D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658624827707D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658562316886D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658561895643D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658593883968D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658561270136D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658558517497D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658557997936D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658569454523D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658473022631D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658535943774D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658503959148D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658536569237D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658535522560D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658539321673D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658539841191D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658528385462D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658586816162D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658561219411D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658561057826D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658557694239D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658556845418D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658556955455D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658566949316D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658759030736D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658554223335D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658577774702D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658555957685D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658511025820D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658555476264D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658553418299D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658540883577D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658530890467D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658338893602D+01
#  intdy--  t (=r1) illegal
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above message,  r1 = -0.4838383838384D+01
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658520066104D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658543615338D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658541881241D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658542362602D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658544420205D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658556237001D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658553005219D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658580142277D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658555906582D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658552356290D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658554643960D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658552712011D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658553159722D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658552697956D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658553710618D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658551432195D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658541601956D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658544833181D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658551619550D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658545481910D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658545126304D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658545140356D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658554222025D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658546405623D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658553708125D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658546218357D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#  intdy--  t (=r1) illegal
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658550927864D+01
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658573171301D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658550650762D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658550206429D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658550103235D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658550144135D+01
#  intdy--  t (=r1) illegal
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658549767237D+01
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658544130445D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658549847011D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658546909679D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658547186604D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658547733718D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658547630608D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658547692852D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658553042080D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658548069414D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658551353593D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658547989715D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658549588595D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658552192280D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658548961195D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658544796330D+01
#  intdy--  t (=r1) illegal
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658549590692D+01
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658549365873D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658549633022D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658524669021D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658548247878D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658545645863D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658552266960D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658548874547D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658548245784D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658548470359D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658548203496D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658549286224D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658552157788D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658543616648D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658545571210D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658549910962D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658549059171D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658549407404D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658549941878D+01
#  intdy--  t (=r1) illegal
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above message,  r1 = -0.4838383838384D+01
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658549499058D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658551740418D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658546484185D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658551873544D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658548549918D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658582420607D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658547925823D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658549907816D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658547894935D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658546097543D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658550595313D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658545964473D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658550721984D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658515420765D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658550144230D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658547928966D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658549743759D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658551279850D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658549320313D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658552020261D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658551193165D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658536619959D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658547115429D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658540144862D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658550447154D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658536781532D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658548515869D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658545817815D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658540993604D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658548961182D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658552579103D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658557608107D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658549012290D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658544678719D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658551806635D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658550542072D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658556108966D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658543194785D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658548874560D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658545259171D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658545680341D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#  intdy--  t (=r1) illegal
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658553405639D+01
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658548776697D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658547295218D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658555319390D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658550502493D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658517698808D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658548941405D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658550819565D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658548337320D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658547390069D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658540230987D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658548428876D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658547334770D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658541932338D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658563620663D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#  intdy--  t (=r1) illegal
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658547692757D+01
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658544127952D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658555782466D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658546644528D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658548823518D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658534218875D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658546557891D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658553490215D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658561369277D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658547242015D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658546031354D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658541729978D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658544348306D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658544432863D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658547017910D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658542519455D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658536470103D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658551111381D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658548894311D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658548092868D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658542056439D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658546726268D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4659742033458D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658589508128D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658559773245D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658557370668D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658555355001D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658553623092D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658554267905D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658554202066D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4657358544930D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658508334264D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658538066021D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658540468404D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658542483849D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658544215460D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658543570775D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658543636603D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658561797001D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658562708356D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658615682163D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658556003332D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658555306400D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658554550593D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658554406288D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658552989988D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658553171384D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658552958837D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658482165656D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658541835599D+01
#  intdy--  t (=r1) illegal
# ...
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658557208843D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658548015967D+01
#  intdy--  t (=r1) illegal
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658548279018D+01
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658548251329D+01
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658552731464D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658548360590D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658549128688D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658548567380D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658540630214D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658548916157D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658549094384D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658548959632D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658545106857D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658549385464D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658545962768D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658553097342D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658548919525D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658548741528D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658549124253D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658550277849D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658548876108D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658548450791D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658544741082D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658551281424D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658548711696D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658547559246D+01
#  intdy--  t (=r1) illegal
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658552983868D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658550513837D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658549272406D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658547769102D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658546556317D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658548114563D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658544854526D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658547323433D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658548563720D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658550208705D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658545901714D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658550087671D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658546313888D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658549783488D+01
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658547000709D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658549911518D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658549270082D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658547749269D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658548707267D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658548053178D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658550852596D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658547925267D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658541203257D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658550001582D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658549202060D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658546984900D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658508491951D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658548946675D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658547451920D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658549592861D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658547835284D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658549577678D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658548889048D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658549466326D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658550452962D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658547628335D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658548243616D+01
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658544071466D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658545695484D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658548258783D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658548566041D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658548370018D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658550861223D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658547384264D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658548633984D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658549019871D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658546976278D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 = -0.4838383838384D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 = -0.4838383838384D+01   r2 = -0.4658548815947D+01
# P22=518.3(1.5),now P13
# P13=-524.9(2.1)
# P22=518.319, -P13=524.895, reldiff=-1e-02

# %% [markdown]
#  P22=483.9(1.4),now P13
# P13=-509.5(1.9)
# P22=483.864, -P13=509.450, reldiff=-5e-02

# %%
plt.figure(figsize=(5,4), dpi=130)
plt.loglog(qlist,reslist22,label='22')
plt.loglog(qlist,np.abs(np.array(reslist13)),label='13')
# plt.plot(qlist,(reslist22-np.abs(np.array(reslist13)))/reslist22,label='13')
# plt.axhline(0, color='k')
plt.xlabel(r"$q$ [$h/\mathrm{Mpc}$]", fontsize=14)
plt.ylabel(r'$P22$', fontsize=14)
plt.xscale('log')
plt.legend()

plt.show()
