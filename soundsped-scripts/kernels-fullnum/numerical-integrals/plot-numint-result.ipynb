# %%
import numpy as np
import matplotlib.pyplot as plt

plt.rcParams.update({
    "text.usetex": True,
    "font.family": "serif",
    "font.serif": ["Computer Modern"],
})

# %%
plt.figure(figsize=(6,4.5),dpi=130)

kplt,dcTc22, dcTc22_EdS, dcTx22, dcTx22_EdS, PL_cc, TL_x =np.loadtxt('/home/fverdian/class/soundspeed-scripts/kernels-fullnum/numerical-integrals/checks-Theta/dT22-kJ0p45-fx0p1-N1000.txt', unpack=True)

kplt,dcTc13, dcTc13_EdS, dcTx13, dcTx13_EdS, PL_cc, TL_x =np.loadtxt('/home/fverdian/class/soundspeed-scripts/kernels-fullnum/numerical-integrals/checks-Theta/dT13-kJ0p45-fx0p1-N1000.txt', unpack=True)

plt.plot(kplt, dcTc13, 'b', label=r'$P^{13}_{\delta_c\Theta_c}$ num', linewidth=1)
plt.plot(kplt, dcTc13_EdS, 'b--', label=r'$P^{13}_{\delta_c\Theta_c}$ EdS', linewidth=1)

plt.plot(kplt, dcTc22, 'r', label=r'$P^{22}_{\delta_c\Theta_c}$', linewidth=1)
plt.plot(kplt, dcTc22_EdS, 'r--', label=r'$P^{22}_{\delta_c\Theta_c}$', linewidth=1)
plt.plot(kplt, dcTc22 + dcTc13, 'purple', label=r'$P^{1l}_{\delta_c\Theta_c}$ num', linewidth=1)

plt.plot(kplt, dcTc22_EdS+dcTc13_EdS, 'gray', linestyle='--', linewidth=0.8, label=r'$P^{1l}_{\delta_c\Theta_c}$ EdS')
# plt.plot(kplt, PL_cc, 'k', linestyle='--', linewidth=0.8, label=r'$P^{1l}_{\delta_c\Theta_c}$ EdS')

plt.axhline(y=0.,linestyle=':', color='k', linewidth=0.3)

plt.xscale('log')
# plt.yscale('log')

plt.ylabel(r"$P_{\delta_c\Theta_c}$", fontsize=15)
plt.legend(fontsize=13, loc='lower left')
plt.xlabel(r'$k$', fontsize=13)
# plt.savefig('/home/fverdian/class/soundspeed-scripts/figure/P-1loop-theory-deltaTheta.pdf', bbox_inches='tight')
plt.show()

# %%
plt.figure(figsize=(6,4.5),dpi=130)

kplt,dcTc22, dcTc22_EdS, dcTx22, dcTx22_EdS, PL_cc, TL_x =np.loadtxt('/home/fverdian/class/soundspeed-scripts/kernels-fullnum/numerical-integrals/checks-Theta/dT22EdSh-kJ0p45-fx0p1-N1000.txt', unpack=True)

kplt,dcTc13, dcTc13_EdS, dcTx13, dcTx13_EdS, PL_cc, TL_x =np.loadtxt('/home/fverdian/class/soundspeed-scripts/kernels-fullnum/numerical-integrals/checks-Theta/dT13EdSh-kJ0p45-fx0p1-N1000.txt', unpack=True)

plt.plot(kplt, dcTx13, 'b', label=r'$P^{13}_{\delta_c\Theta_\chi}$ num', linewidth=1)
plt.plot(kplt, dcTx13_EdS, 'b--', label=r'$P^{13}_{\delta_c\Theta_\chi}$ EdS', linewidth=1)

plt.plot(kplt, dcTx22, 'r', label=r'$P^{22}_{\delta_c\Theta_\chi}$', linewidth=1)
plt.plot(kplt, dcTx22_EdS, 'r--', label=r'$P^{22}_{\delta_c\Theta_\chi}$', linewidth=1)

plt.plot(kplt, dcTx22 + dcTx13, 'purple', label=r'$P^{1l}_{\delta_c\Theta_\chi}$ num', linewidth=1)

plt.plot(kplt, dcTx22_EdS+dcTx13_EdS, 'gray', linestyle='--', linewidth=0.8, label=r'$P^{1l}_{\delta_c\Theta_\chi}$ EdS')

kplt,dcTc22, dcTc22_EdS, dcTx22, dcTx22_EdS, PL_cc, TL_x =np.loadtxt('/home/fverdian/class/soundspeed-scripts/kernels-fullnum/numerical-integrals/checks-Theta/dT22-kJ0p45-fx0p1-N1000.txt', unpack=True)

kplt,dcTc13, dcTc13_EdS, dcTx13, dcTx13_EdS, PL_cc, TL_x =np.loadtxt('/home/fverdian/class/soundspeed-scripts/kernels-fullnum/numerical-integrals/checks-Theta/dT13-kJ0p45-fx0p1-N1000.txt', unpack=True)

# plt.plot(kplt, dcTx22 + dcTx13, 'm--', label=r'$P^{1l}_{\delta_c\Theta_\chi}$ num', linewidth=1)

# plt.plot(kplt,dcTx13_EdS, 'b:', label=r'$P^{1l}_{\delta_c\Theta_\chi}$ num', linewidth=1)

plt.axhline(y=0.,linestyle=':', color='k', linewidth=0.3)

plt.xscale('log')
plt.ylabel(r"$P_{\delta_c\Theta_\chi}$", fontsize=15)
plt.legend(fontsize=13, loc='lower right')
plt.xlabel(r'$k$', fontsize=13)
# plt.savefig('/home/fverdian/class/soundspeed-scripts/figure/P-1loop-theory-deltaTheta.pdf', bbox_inches='tight')
plt.show()

# %% [markdown]
# Now plot the relative differences

# %%
plt.figure(figsize=(6,4.5),dpi=130)

kplt,dcTc22, dcTc22_EdS, dcTx22, dcTx22_EdS, PL_cc, TL_x =np.loadtxt('/home/fverdian/class/soundspeed-scripts/kernels-fullnum/numerical-integrals/checks-Theta/dT22-kJ0p45-fx0p1-N1000.txt', unpack=True)

kplt,dcTc13, dcTc13_EdS, dcTx13, dcTx13_EdS, PL_cc, TL_x =np.loadtxt('/home/fverdian/class/soundspeed-scripts/kernels-fullnum/numerical-integrals/checks-Theta/dT13-kJ0p45-fx0p1-N1000.txt', unpack=True)

plt.plot(kplt, (dcTc13-dcTc13_EdS)/np.abs(dcTc13_EdS), 'b', label=r'$P^{13}_{\delta_c\Theta_c}$ num', linewidth=1)

plt.plot(kplt, (dcTc22-dcTc22_EdS)/np.abs(dcTc22_EdS), 'r', label=r'$P^{22}_{\delta_c\Theta_c}$', linewidth=1)
# plt.plot(kplt, ((dcTc22 + dcTc13)-(dcTc22_EdS+dcTc13_EdS))/np.abs(dcTc22_EdS+dcTc13_EdS), 'purple', label=r'$P^{1l}_{\delta_c\Theta_c}$ num', linewidth=1)

plt.axhline(y=0.,linestyle=':', color='k', linewidth=0.3)

plt.xscale('log')
# plt.yscale('log')

plt.ylabel(r"$P_{\delta_c\Theta_c}$", fontsize=15)
plt.legend(fontsize=13, loc='lower left')
plt.xlabel(r'$k$', fontsize=13)
# plt.savefig('/home/fverdian/class/soundspeed-scripts/figure/P-1loop-theory-deltaTheta.pdf', bbox_inches='tight')
plt.show()

# %%
plt.figure(figsize=(6,4.5),dpi=130)

kplt,dcTc22, dcTc22_EdS, dcTx22, dcTx22_EdS, PL_cc, TL_x =np.loadtxt('/home/fverdian/class/soundspeed-scripts/kernels-fullnum/numerical-integrals/checks-Theta/dT22EdSh-kJ0p45-fx0p1-N1000.txt', unpack=True)

kplt,dcTc13, dcTc13_EdS, dcTx13, dcTx13_EdS, PL_cc, TL_x =np.loadtxt('/home/fverdian/class/soundspeed-scripts/kernels-fullnum/numerical-integrals/checks-Theta/dT13EdSh-kJ0p45-fx0p1-N1000.txt', unpack=True)

# plt.plot(kplt, dcTx13/dcTx13_EdS, 'b', label=r'$P^{13}_{\delta_c\Theta_\chi}$ num', linewidth=1)

# plt.plot(kplt, dcTx22/dcTx22_EdS, 'r', label=r'$P^{22}_{\delta_c\Theta_\chi}$', linewidth=1)

plt.plot(kplt, (dcTx22 + dcTx13)/(dcTx22_EdS+dcTx13_EdS), 'purple', label=r'$P^{1l}_{\delta_c\Theta_\chi}$ num', linewidth=1)

# plt.plot(kplt, dcTx22_EdS+dcTx13_EdS, 'gray', linestyle='--', linewidth=0.8, label=r'$P^{1l}_{\delta_c\Theta_\chi}$ EdS')

plt.axhline(y=0.,linestyle=':', color='k', linewidth=0.3)

plt.xscale('log')
plt.ylabel(r"$P_{\delta_c\Theta_\chi}$", fontsize=15)
plt.legend(fontsize=13, loc='lower right')
plt.xlabel(r'$k$', fontsize=13)
plt.ylim([0.,1.])
# plt.savefig('/home/fverdian/class/soundspeed-scripts/figure/P-1loop-theory-deltaTheta.pdf', bbox_inches='tight')
plt.show()

# %% [markdown]
# -----
# P c chi

# %%
plt.figure(figsize=(5,3.5),dpi=140)

kplt,lcc, lcc_EdS,lcx, lcx_EdS,Plin,T_chi=np.loadtxt('/home/fverdian/class/soundspeed-scripts/kernels-fullnum/numerical-integrals/numint-results/Pcx-kJ0p45-fx0p1-N5000.txt', unpack=True)
plt.plot(kplt, np.abs((Plin+lcc_EdS)/(Plin+lcc)-1), 'b', label=r'$P_{cc}$, $k_J=0.45$', linewidth=1)
plt.plot(kplt, np.abs((Plin*T_chi+lcx_EdS)/(Plin*T_chi+lcx)-1), 'g', label=r'$P_{c\chi}$, $k_J=0.45$', linewidth=1)


kplt,lcc, lcc_EdS,ldT,ldT_EdS,Plin=np.loadtxt('/home/fverdian/class/soundspeed-scripts/kernels-fullnum/numerical-integrals/numint-results/Pcc-kJ0p2-fx0p1-N2000.txt', unpack=True)
plt.plot(kplt, np.abs((Plin+lcc_EdS)/(Plin+lcc)-1), 'r--', label=r'$P_{cc}$, $k_J=0.2$', linewidth=1)
plt.plot(kplt, np.abs((Plin+ldT_EdS)/(Plin+ldT)-1), color='darkorange', linestyle='--', label=r'$P_{\delta_{c}\Theta_c}$, $k_J=0.2$', linewidth=1)


plt.xscale('log')
plt.yscale('log')
plt.ylabel(r"$\Big|\frac{P^{\Lambda \mathrm{CDM\,kers}}}{P^\mathrm{full}}-1\Big|$", fontsize=13)
plt.legend()
plt.xlabel(r'$k$', fontsize=13)
plt.ylim([1.e-4,1.01])
# plt.savefig('/home/fverdian/class/soundspeed-scripts/figure/P-1loop-pheno-deltaTheta.pdf', bbox_inches='tight')

plt.show()

# %% [markdown]
# -----
